# %% [markdown]
# # Statistical Intuitions and Applications
#
# ## Assignment - 1 ##

# %%
# Sample size
import random
s=random.randint(51,81)
print("Sample size = n =", s)
# Out:
# Sample size = n = 70

# %%
# CSV File
import pandas as pd
original_data = pd.read_csv("https://raw.githubusercontent.com/zu-math/SIA-Fall-2023-Dataset/main/mod_mea_f.csv")
df1=original_data.sample(70)  # Add your sample size here 
df1.to_csv(r'C:\Users\user\Hamdan\Hamdan.csv')

# %% [markdown]
# **Note: If you have successfully run above codes then a CSV file is already generated in your device at the same location which can be accessed using code below.**
#
# Once you have started working on the assignment, it is highly recommended not to run above codes as it will generate new "CSV File" which will give different answers. The codes below will work each time you open the assignment without the need to run above codes.

# %%
# Access the file and have a look at the dataset
df = pd.read_csv(r'C:\Users\user\Hamdan\Hamdan.csv') 
df = pd.DataFrame(df)
df = df.set_index('Unnamed: 0', drop=True)
df.columns = df.columns.str.strip() 
df.head(100)
# Out:
#             Academic_Year Institution_Type_EN Campus_Zone_EN LocalFlag_EN  \
# Unnamed: 0
# 347                  2020         Non-Federal       Fujairah        Expat
# 184                  2017             Federal        Sharjah        Local
# 231                  2018             Federal        Sharjah        Expat
# 336                  2020         Non-Federal      Abu Dhabi        Local
# 291                  2019         Non-Federal          Ajman        Expat
# ...                   ...                 ...            ...          ...
# 330                  2020             Federal        Sharjah        Expat
# 129                  2016             Federal          Dubai        Local
# 172                  2017             Federal          Dubai        Expat
# 300                  2019         Non-Federal       Fujairah        Local
# 199                  2017         Non-Federal       Fujairah        Expat
#
#            Gender_EN  Bachelors  Certificate  Diploma  Doctorate  \
# ...

# %% [markdown]
# ## Question 1

# %% [markdown]
# Your first task is to briefly introduce the study and all the main variables in it using a brief report with clear wordings. Identify all the variables in the dataset. Explain what will you be analyzing in this report to the readers.

# %% [markdown]
# **Answer 1.**

# %% [markdown]
# Question 1:
#
# Introduction
# print("This study analyzes a dataset from the Dubai Statistics Center. The dataset contains information related to academic years, institution types, campus zones, local flags, gender, and various academic degree programs.")
# print("We will explore and analyze this dataset to gain insights into the educational landscape, including the distribution of students across different institution types, academic programs, and genders.")
#
# Variable Identification
# print("\nVariables in the Dataset:")
# print("1. Unnamed: A unique identifier (may not be relevant for analysis)")
# print("2. Academic_Year: The academic year of the data")
# print("3. Institution_Type_EN: The type of institution")
# print("4. Campus_Zone_EN: The campus zone")
# print("5. LocalFlag_EN: A flag indicating local status")
# print("6. Gender_EN: Gender of the students")
# print("7. Bachelors: Count of students pursuing a Bachelor's degree")
# print("8. Certificate: Count of students pursuing a Certificate program")
# print("9. Diploma: Count of students pursuing a Diploma program")
# print("10. Doctorate: Count of students pursuing a Doctorate degree")
# print("11. Graduate Diploma: Count of students pursuing a Graduate Diploma")
# print("12. Higher Diploma: Count of students pursuing a Higher Diploma")
# print("13. Masters: Count of students pursuing a Master's degree")
# print("14. Total: Total count of students in the dataset")
#
# Analysis Plan
# print("\nIn this report, we will analyze and explore various aspects of the dataset, including:")
# print("- Distribution of students across different academic programs")
# print("- Comparison of student counts based on gender")
# print("- Trends in academic enrollment over academic years")
# print("- Relationships between variables, such as academic program and gender")

# %% [markdown]
# ## Question 2

# %% [markdown]
# In this task, you will generate descriptive statistics for all the quantitative variables in the dataset using the histograms and describe their distributions in terms of shape, center, spread, and presence of outliers. The codes below will provide you the histogram and five-number summary of the relevant column. You need to replace '???' with column name.

# %% [markdown]
# **Answer 2.**

# %%
import matplotlib.pyplot as plt
import numpy as np


data = df['Bachelors']

# Generate a histogram
plt.hist(data, edgecolor='k', bins=10)  # Adjust the number of bins as needed
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Histogram of Bachelors')

# Calculate and display statistics
count = len(data)
mean = np.mean(data)
median = np.median(data)
std_dev = np.std(data)
min_val = np.min(data)
q1 = np.percentile(data, 25)
q3 = np.percentile(data, 75)
max_val = np.max(data)

# Calculate potential outliers using the IQR method
iqr = q3 - q1
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr
outliers = [x for x in data if x < lower_bound or x > upper_bound]

# Describe shape
if skew(data) > 0:
    shape_description = "Positive skew (right-skewed)"
elif skew(data) < 0:
    shape_description = "Negative skew (left-skewed)"
else:
    shape_description = "Symmetric (bell-shaped)"

# Display descriptions
print("Shape of the Distribution:", shape_description)
print("Center of the Distribution:")
print("Mean:", mean)
print("Median:", median)
print("Spread of the Distribution:")
print("Standard Deviation:", std_dev)
print("Five-Number Summary:")
print("Min:", min_val)
print("25th Percentile (Q1):", q1)
print("Median (50th Percentile):", median)
print("75th Percentile (Q3):", q3)
print("Max:", max_val)
print("Presence of Outliers:")
print("Number of potential outliers:", len(outliers))

plt.show()
# Out:
# Shape of the Distribution: Positive skew (right-skewed)
# Center of the Distribution:
# Mean: 417.1714285714286
# Median: 300.5
# Spread of the Distribution:
# Standard Deviation: 412.2086493661248
# Five-Number Summary:
# Min: 1
# 25th Percentile (Q1): 44.5
# Median (50th Percentile): 300.5
# 75th Percentile (Q3): 677.75
# Max: 1572
# Presence of Outliers:
# Number of potential outliers: 0

# %% [markdown]
# ## Question 3

# %% [markdown]
# Your next task is to choose three quantitative variables of your choice and two catagorical variables.
#
# Suppose you have chosen column 'Masters' as a quantiative and 'Gender_EN' for a categorical variable. Replicate the steps for task below.
#
# **3a.** Generate a grouped box plot to compare the distribution of Masters degree holders among male and female students. Describe your observations referring to the five-number-summaries of both genders.
#
# In the same way, do it for other quantitative and categorical variables. This should give rise to six cases.
#
# **3b.** Discuss any patterns you observe between male and female genders when you compare them.

# %% [markdown]
# **Answer 3a.**
#
# (Begin your answer by explicitly mentioning which three quantitative and two categorical variables you have chosen.)
#
# Case 1.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Function to describe the data
def describe_data(data):
    count = len(data)
    median = data.median()
    
    # Calculate potential outliers using the IQR method
    q1 = data.quantile(0.25)
    q3 = data.quantile(0.75)
    iqr = q3 - q1
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr
    outliers = [x for x in data if x < lower_bound or x > upper_bound]
    
    return {
        'Count': count,
        'Median': median,
        'Potential Outliers': len(outliers),
        'Spread (IQR)': iqr
    }

# Cases
cases = [
    {'quantitative_variable': 'Masters', 'categorical_variable': 'Gender_EN'},
    # Add other cases as needed
]

# Iterate through cases
for case in cases:
    quantitative_variable = case['quantitative_variable']
    categorical_variable = case['categorical_variable']

    # Create a grouped box plot for the case
    plt.figure(figsize=(8, 6))
    sns.boxplot(x=categorical_variable, y=quantitative_variable, data=df)
    plt.title(f'Grouped Box Plot for {quantitative_variable} by {categorical_variable}')
    plt.xlabel(categorical_variable)
    plt.ylabel(quantitative_variable)
    plt.show()

    # Describe the observations referring to the five-number summaries, median, presence of outliers, and spread
    summary = df.groupby(categorical_variable)[quantitative_variable].describe()
    additional_description = describe_data(df[quantitative_variable])
    
    print(f"Summary for {quantitative_variable} by {categorical_variable}:")
    print(summary)
    
    print("\nAdditional Description:")
    for key, value in additional_description.items():
        print(f"{key}: {value}")
    
    print("\n" + "="*50 + "\n")  # Separator between cases
# Out:
# Summary for Masters by Gender_EN:
#            count        mean         std  min    25%   50%     75%    max
# Gender_EN
# Female      40.0  116.175000  125.824438  1.0  19.50  86.0  135.75  477.0
# Male        30.0  104.466667  132.486755  1.0  28.75  57.0  132.00  562.0
#
# Additional Description:
# Count: 70
# Median: 66.5
# Potential Outliers: 7
# Spread (IQR): 111.0
#
# ...

# %% [markdown]
# **Case 2.**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Function to describe the data
def describe_data(data):
    count = len(data)
    median = data.median()
    
    # Calculate potential outliers using the IQR method
    q1 = data.quantile(0.25)
    q3 = data.quantile(0.75)
    iqr = q3 - q1
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr
    outliers = [x for x in data if x < lower_bound or x > upper_bound]
    
    return {
        'Count': count,
        'Median': median,
        'Potential Outliers': len(outliers),
        'Spread (IQR)': iqr
    }

# Cases
cases = [
    {'quantitative_variable': 'Doctorate', 'categorical_variable': 'Gender_EN'},
    # Add other cases as needed
]

# Iterate through cases
for case in cases:
    quantitative_variable = case['quantitative_variable']
    categorical_variable = case['categorical_variable']

    # Create a grouped box plot for the case
    plt.figure(figsize=(8, 6))
    sns.boxplot(x=categorical_variable, y=quantitative_variable, data=df)
    plt.title(f'Grouped Box Plot for {quantitative_variable} by {categorical_variable}')
    plt.xlabel(categorical_variable)
    plt.ylabel(quantitative_variable)
    plt.show()

    # Describe the observations referring to the five-number summaries, median, presence of outliers, and spread
    summary = df.groupby(categorical_variable)[quantitative_variable].describe()
    additional_description = describe_data(df[quantitative_variable])
    
    print(f"Summary for {quantitative_variable} by {categorical_variable}:")
    print(summary)
    
    print("\nAdditional Description:")
    for key, value in additional_description.items():
        print(f"{key}: {value}")
    
    print("\n" + "="*50 + "\n")  # Separator between cases
# Out:
# Summary for Doctorate by Gender_EN:
#            count  mean       std  min  25%  50%  75%   max
# Gender_EN
# Female      40.0  7.75  2.133373  2.0  8.0  8.0  8.0  15.0
# Male        30.0  7.30  2.135900  1.0  8.0  8.0  8.0  11.0
#
# Additional Description:
# Count: 70
# Median: 8.0
# Potential Outliers: 22
# Spread (IQR): 0.0
#
# ...

# %% [markdown]
# **Case 3.**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Function to describe the data
def describe_data(data):
    count = len(data)
    median = data.median()
    
    # Calculate potential outliers using the IQR method
    q1 = data.quantile(0.25)
    q3 = data.quantile(0.75)
    iqr = q3 - q1
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr
    outliers = [x for x in data if x < lower_bound or x > upper_bound]
    
    return {
        'Count': count,
        'Median': median,
        'Potential Outliers': len(outliers),
        'Spread (IQR)': iqr
    }

# Cases
cases = [
    {'quantitative_variable': 'Graduate Diploma', 'categorical_variable': 'Gender_EN'},
    # Add other cases as needed
]

# Iterate through cases
for case in cases:
    quantitative_variable = case['quantitative_variable']
    categorical_variable = case['categorical_variable']

    # Create a grouped box plot for the case
    plt.figure(figsize=(8, 6))
    sns.boxplot(x=categorical_variable, y=quantitative_variable, data=df)
    plt.title(f'Grouped Box Plot for {quantitative_variable} by {categorical_variable}')
    plt.xlabel(categorical_variable)
    plt.ylabel(quantitative_variable)
    plt.show()

    # Describe the observations referring to the five-number summaries, median, presence of outliers, and spread
    summary = df.groupby(categorical_variable)[quantitative_variable].describe()
    additional_description = describe_data(df[quantitative_variable])
    
    print(f"Summary for {quantitative_variable} by {categorical_variable}:")
    print(summary)
    
    print("\nAdditional Description:")
    for key, value in additional_description.items():
        print(f"{key}: {value}")
    
    print("\n" + "="*50 + "\n")  # Separator between cases
# Out:
# Summary for Graduate Diploma by Gender_EN:
#            count       mean         std  min   25%   50%   75%    max
# Gender_EN
# Female      40.0  88.775000  139.674803  1.0  51.0  80.0  80.0  927.0
# Male        30.0  53.066667   31.358806  2.0  18.0  80.0  80.0   80.0
#
# Additional Description:
# Count: 70
# Median: 80.0
# Potential Outliers: 1
# Spread (IQR): 62.0
#
# ...

# %% [markdown]
# **Case 4.**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Function to describe the data
def describe_data(data):
    count = len(data)
    median = data.median()
    
    # Calculate potential outliers using the IQR method
    q1 = data.quantile(0.25)
    q3 = data.quantile(0.75)
    iqr = q3 - q1
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr
    outliers = [x for x in data if x < lower_bound or x > upper_bound]
    
    return {
        'Count': count,
        'Median': median,
        'Potential Outliers': len(outliers),
        'Spread (IQR)': iqr
    }

# Cases
cases = [
    {'quantitative_variable': 'Certificate', 'categorical_variable': 'Gender_EN'},
    # Add other cases as needed
]

# Iterate through cases
for case in cases:
    quantitative_variable = case['quantitative_variable']
    categorical_variable = case['categorical_variable']

    # Create a grouped box plot for the case
    plt.figure(figsize=(8, 6))
    sns.boxplot(x=categorical_variable, y=quantitative_variable, data=df)
    plt.title(f'Grouped Box Plot for {quantitative_variable} by {categorical_variable}')
    plt.xlabel(categorical_variable)
    plt.ylabel(quantitative_variable)
    plt.show()

    # Describe the observations referring to the five-number summaries, median, presence of outliers, and spread
    summary = df.groupby(categorical_variable)[quantitative_variable].describe()
    additional_description = describe_data(df[quantitative_variable])
    
    print(f"Summary for {quantitative_variable} by {categorical_variable}:")
    print(summary)
    
    print("\nAdditional Description:")
    for key, value in additional_description.items():
        print(f"{key}: {value}")
    
    print("\n" + "="*50 + "\n")  # Separator between cases
# Out:
# Summary for Certificate by Gender_EN:
#            count    mean        std  min  25%   50%   75%    max
# Gender_EN
# Female      40.0  17.975  18.267931  1.0  7.5  19.0  19.0  117.0
# Male        30.0  12.900   6.890023  1.0  6.0  19.0  19.0   19.0
#
# Additional Description:
# Count: 70
# Median: 19.0
# Potential Outliers: 2
# Spread (IQR): 13.0
#
# ...

# %% [markdown]
# **Case 5.**
#
# (Begin your answer by explicitly mentioning which three quantitative and two categorical variables you have chosen.)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Function to describe the data
def describe_data(data):
    count = len(data)
    median = data.median()
    
    # Calculate potential outliers using the IQR method
    q1 = data.quantile(0.25)
    q3 = data.quantile(0.75)
    iqr = q3 - q1
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr
    outliers = [x for x in data if x < lower_bound or x > upper_bound]
    
    return {
        'Count': count,
        'Median': median,
        'Potential Outliers': len(outliers),
        'Spread (IQR)': iqr
    }

# Cases
cases = [
    {'quantitative_variable': 'Bachelors', 'categorical_variable': 'Gender_EN'},
    # Add other cases as needed
]

# Iterate through cases
for case in cases:
    quantitative_variable = case['quantitative_variable']
    categorical_variable = case['categorical_variable']

    # Create a grouped box plot for the case
    plt.figure(figsize=(8, 6))
    sns.boxplot(x=categorical_variable, y=quantitative_variable, data=df)
    plt.title(f'Grouped Box Plot for {quantitative_variable} by {categorical_variable}')
    plt.xlabel(categorical_variable)
    plt.ylabel(quantitative_variable)
    plt.show()

    # Describe the observations referring to the five-number summaries, median, presence of outliers, and spread
    summary = df.groupby(categorical_variable)[quantitative_variable].describe()
    additional_description = describe_data(df[quantitative_variable])
    
    print(f"Summary for {quantitative_variable} by {categorical_variable}:")
    print(summary)
    
    print("\nAdditional Description:")
    for key, value in additional_description.items():
        print(f"{key}: {value}")
    
    print("\n" + "="*50 + "\n")  # Separator between cases
# Out:
# Summary for Bachelors by Gender_EN:
#            count        mean         std  min    25%    50%     75%     max
# Gender_EN
# Female      40.0  423.125000  462.175635  1.0  39.75  245.5  699.00  1572.0
# Male        30.0  409.233333  350.377302  4.0  50.00  390.0  663.75   991.0
#
# Additional Description:
# Count: 70
# Median: 300.5
# Potential Outliers: 0
# Spread (IQR): 633.25
#
# ...

# %% [markdown]
# **Case 6.**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Function to describe the data
def describe_data(data):
    count = len(data)
    median = data.median()
    
    # Calculate potential outliers using the IQR method
    q1 = data.quantile(0.25)
    q3 = data.quantile(0.75)
    iqr = q3 - q1
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr
    outliers = [x for x in data if x < lower_bound or x > upper_bound]
    
    return {
        'Count': count,
        'Median': median,
        'Potential Outliers': len(outliers),
        'Spread (IQR)': iqr
    }

# Cases
cases = [
    {'quantitative_variable': 'Diploma', 'categorical_variable': 'Gender_EN'},
    # Add other cases as needed
]

# Iterate through cases
for case in cases:
    quantitative_variable = case['quantitative_variable']
    categorical_variable = case['categorical_variable']

    # Create a grouped box plot for the case
    plt.figure(figsize=(8, 6))
    sns.boxplot(x=categorical_variable, y=quantitative_variable, data=df)
    plt.title(f'Grouped Box Plot for {quantitative_variable} by {categorical_variable}')
    plt.xlabel(categorical_variable)
    plt.ylabel(quantitative_variable)
    plt.show()

    # Describe the observations referring to the five-number summaries, median, presence of outliers, and spread
    summary = df.groupby(categorical_variable)[quantitative_variable].describe()
    additional_description = describe_data(df[quantitative_variable])
    
    print(f"Summary for {quantitative_variable} by {categorical_variable}:")
    print(summary)
    
    print("\nAdditional Description:")
    for key, value in additional_description.items():
        print(f"{key}: {value}")
    
    print("\n" + "="*50 + "\n")  # Separator between cases
# Out:
# Summary for Diploma by Gender_EN:
#            count    mean        std  min   25%   50%   75%    max
# Gender_EN
# Female      40.0  57.075  84.005002  1.0  7.75  47.5  55.0  396.0
# Male        30.0  33.000  33.969560  1.0  7.50  15.5  55.0  136.0
#
# Additional Description:
# Count: 70
# Median: 32.0
# Potential Outliers: 5
# Spread (IQR): 47.75
#
# ...

# %% [markdown]
# **Answer 3b.**

# %% [markdown]
# In the analysis of six different cases involving three quantitative variables and two categorical variables, we examined the distributions of these variables among male and female students. Here are the key observations and patterns:
#
# Case 1: Masters vs. Gender_EN
#
# In this case, we compared the distribution of Masters degrees between male and female students.
# Both genders had potential outliers in their Masters degree counts.
# The spread (interquartile range, IQR) of Masters degrees for both genders was substantial, indicating a wide variation in the number of Masters degrees among students.
#
# Case 2: Doctorate vs. Gender_EN
#
# For Doctorate degrees, both male and female students had similar median values.
# Notably, a significant number of potential outliers were observed in both genders, suggesting variations in the number of Doctorate degrees earned.
#
# Case 3: Graduate Diploma vs. Gender_EN
#
# In the case of Graduate Diplomas, females had a wider spread of values compared to males.
# Only one potential outlier was observed among females.
# The median for males and females was the same (80.0), but the distribution for females had more variability.
#
# Case 4: Certificate vs. Gender_EN
#
# Females had a slightly higher mean Certificate count compared to males.
# Both genders had a similar median value of 19.0, but there were a couple of potential outliers in both groups.
# The spread (IQR) was larger for females, indicating greater variability in Certificate counts.
#
# Case 5: Bachelors vs. Gender_EN
#
# In this case, the distribution of Bachelors degrees showed similar medians for both genders.
# There were no potential outliers in either group.
# However, the IQR for females was larger, suggesting greater variability in the number of Bachelors degrees.
# Case 6: Diploma vs. Gender_EN
#
# Both males and females had a similar median for Diploma counts.
# Both genders had some potential outliers.
# The spread (IQR) was slightly larger for females, indicating variability in Diploma counts.
# Overall, these analyses reveal that there are differences in the distributions of quantitative variables between male and female genders. These differences can be seen in terms of the spread, potential outliers, and, in some cases, the central tendency (median) of the variables.

# %% [markdown]
# ## Question 4

# %% [markdown]
# In this task, you will work on the scatterplots to examine the relationship between dependent and independent variables. Treat 'Academic_Year' as an independent variable and use any of the two dependent variables you chose in Question 3 as the dependent variables.
#
# **4a.** Create separate scatterplots to examine the relationship between the dependent variables and the independent variable. Describe the scatterplots in terms of the form, strength, and direction of the relationships. Further examine if the relationship between the independent variable and each of the dependent variables varies by gender (you will need to create scatterplots separately for each gender to answer this question.)
#
# In the same way, do it for other quantitative variables. Now change the categorical variable and replicate calculations. This should give rise to ten cases.
#
# **4b.** Explain in simple words what you observed by reporting your findings.

# %% [markdown]
# **Answer 4a.**
#
# (Begin your answer by explicitly mentioning which three quantitative and two categorical variables you have chosen.)
#
# **Case 1.**

# %%
# Case 1.  

from scipy.stats import pearsonr


male_data = df[df['Gender_EN'] == 'Male']
female_data = df[df['Gender_EN'] == 'Female']

# Create scatterplots for Masters vs. Academic_Year for both genders
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.scatterplot(x='Academic_Year', y='Masters', data=male_data)
plt.title('Masters vs. Academic_Year (Male)')
plt.xlabel('Academic_Year')
plt.ylabel('Masters')



plt.subplot(1, 2, 2)
sns.scatterplot(x='Academic_Year', y='Masters', data=female_data)
plt.title('Masters vs. Academic_Year (Female)')
plt.xlabel('Academic_Year')
plt.ylabel('Masters')


# Calculate correlation coefficient for male data
corr_coefficient_male, _ = pearsonr(male_data['Academic_Year'], male_data['Masters'])
print(f"Correlation Coefficient (Male): {corr_coefficient_male:.2f}")

# Calculate correlation coefficient for female data
corr_coefficient_female, _ = pearsonr(female_data['Academic_Year'], female_data['Masters'])
print(f"Correlation Coefficient (Female): {corr_coefficient_female:.2f}")


plt.tight_layout()
plt.show()
# Out:
# Correlation Coefficient (Male): 0.16
# Correlation Coefficient (Female): 0.02

# %% [markdown]
# **Case 2.**

# %%
# Case 2 


# Create scatterplots for Academic_Year vs. Academic_Year for both genders
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.scatterplot(x='Academic_Year', y='Higher Diploma', data=male_data)
plt.title('Higher Diploma vs. Academic_Year (Male)')
plt.xlabel('Academic_Year')
plt.ylabel('Higher Diploma')

plt.subplot(1, 2, 2)
sns.scatterplot(x='Academic_Year', y='Higher Diploma', data=female_data)
plt.title('Higher Diploma vs. Academic_Year (Female)')
plt.xlabel('Academic_Year')
plt.ylabel('Higher Diploma')

# Calculate correlation coefficient for male data
corr_coefficient_male, _ = pearsonr(male_data['Academic_Year'], male_data['Higher Diploma'])
print(f"Correlation Coefficient (Male): {corr_coefficient_male:.2f}")

# Calculate correlation coefficient for female data
corr_coefficient_female, _ = pearsonr(female_data['Academic_Year'], female_data['Higher Diploma'])
print(f"Correlation Coefficient (Female): {corr_coefficient_female:.2f}")

plt.tight_layout()
plt.show()
# Out:
# Correlation Coefficient (Male): -0.22
# Correlation Coefficient (Female): 0.31

# %% [markdown]
# **Case 3.**

# %%
# Case 3 

# Create scatterplots for Doctorate vs. Academic_Year for both genders
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.scatterplot(x='Academic_Year', y='Doctorate', data=male_data)
plt.title('Doctorate vs. Academic_Year (Male)')
plt.xlabel('Academic_Year')
plt.ylabel('Doctorate')

plt.subplot(1, 2, 2)
sns.scatterplot(x='Academic_Year', y='Doctorate', data=female_data)
plt.title('Doctorate vs. Academic_Year (Female)')
plt.xlabel('Academic_Year')
plt.ylabel('Doctorate')


# Calculate correlation coefficient for male data
corr_coefficient_male, _ = pearsonr(male_data['Academic_Year'], male_data['Doctorate'])
print(f"Correlation Coefficient (Male): {corr_coefficient_male:.2f}")

# Calculate correlation coefficient for female data
corr_coefficient_female, _ = pearsonr(female_data['Academic_Year'], female_data['Doctorate'])
print(f"Correlation Coefficient (Female): {corr_coefficient_female:.2f}")

plt.tight_layout()
plt.show()
# Out:
# Correlation Coefficient (Male): -0.01
# Correlation Coefficient (Female): 0.20

# %% [markdown]
# **Case 4.**

# %%
# Case 4

# Create scatterplots for Diploma vs. Academic_Year for both genders
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.scatterplot(x='Academic_Year', y='Diploma', data=male_data)
plt.title('Diploma vs. Academic_Year (Male)')
plt.xlabel('Academic_Year')
plt.ylabel('Diploma')

plt.subplot(1, 2, 2)
sns.scatterplot(x='Academic_Year', y='Diploma', data=female_data)
plt.title('Diploma vs. Academic_Year (Female)')
plt.xlabel('Academic_Year')
plt.ylabel('Diploma')


# Calculate correlation coefficient for male data
corr_coefficient_male, _ = pearsonr(male_data['Academic_Year'], male_data['Diploma'])
print(f"Correlation Coefficient (Male): {corr_coefficient_male:.2f}")

# Calculate correlation coefficient for female data
corr_coefficient_female, _ = pearsonr(female_data['Academic_Year'], female_data['Diploma'])
print(f"Correlation Coefficient (Female): {corr_coefficient_female:.2f}")

plt.tight_layout()
plt.show()
# Out:
# Correlation Coefficient (Male): -0.36
# Correlation Coefficient (Female): -0.24

# %% [markdown]
# **Case 5.**

# %%
# Case 5

# Create scatterplots for Certificate vs. Academic_Year for both genders
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.scatterplot(x='Academic_Year', y='Certificate', data=male_data)
plt.title('Certificate vs. Academic_Year (Male)')
plt.xlabel('Academic_Year')
plt.ylabel('Certificate')

plt.subplot(1, 2, 2)
sns.scatterplot(x='Academic_Year', y='Certificate', data=female_data)
plt.title('Certificate vs. Academic_Year (Female)')
plt.xlabel('Academic_Year')
plt.ylabel('Certificate')

# Calculate correlation coefficient for male data
corr_coefficient_male, _ = pearsonr(male_data['Academic_Year'], male_data['Certificate'])
print(f"Correlation Coefficient (Male): {corr_coefficient_male:.2f}")

# Calculate correlation coefficient for female data
corr_coefficient_female, _ = pearsonr(female_data['Academic_Year'], female_data['Certificate'])
print(f"Correlation Coefficient (Female): {corr_coefficient_female:.2f}")

plt.tight_layout()
plt.show()
# Out:
# Correlation Coefficient (Male): -0.20
# Correlation Coefficient (Female): 0.14

# %% [markdown]
# **Case 6.**

# %%
# Case 6. Code Here. 

# Create scatterplots for Bachelors vs. Academic_Year for both genders
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.scatterplot(x='Academic_Year', y='Bachelors', data=male_data)
plt.title('Bachelors vs. Academic_Year (Male)')
plt.xlabel('Academic_Year')
plt.ylabel('Bachelors')

plt.subplot(1, 2, 2)
sns.scatterplot(x='Academic_Year', y='Bachelors', data=female_data)
plt.title('Bachelors vs. Academic_Year (Female)')
plt.xlabel('Academic_Year')
plt.ylabel('Bachelors')

# Calculate correlation coefficient for male data
corr_coefficient_male, _ = pearsonr(male_data['Academic_Year'], male_data['Bachelors'])
print(f"Correlation Coefficient (Male): {corr_coefficient_male:.2f}")

# Calculate correlation coefficient for female data
corr_coefficient_female, _ = pearsonr(female_data['Academic_Year'], female_data['Bachelors'])
print(f"Correlation Coefficient (Female): {corr_coefficient_female:.2f}")

plt.tight_layout()
plt.show()
# Out:
# Correlation Coefficient (Male): 0.32
# Correlation Coefficient (Female): -0.04

# %% [markdown]
# **Answer 4b.**

# %% [markdown]
# Case 1: Masters vs. Academic_Year
#
# For males, there is a weak positive relationship (correlation coefficient: 0.16) between the number of Masters degrees and Academic Year.
# For females, the relationship is very weak (correlation coefficient: 0.02), suggesting little to no clear association between the two variables.
#
# Case 2: Doctorate vs. Academic_Year
#
# For males, there is a weak negative relationship (correlation coefficient: -0.22) between the number of Doctorate degrees and Academic Year.
# For females, the relationship is moderate (correlation coefficient: 0.31), indicating a positive correlation between the variables.
#
# Case 3: Graduate Diploma vs. Academic_Year
#
# For males, there is almost no relationship (correlation coefficient: -0.01) between the number of Graduate Diplomas and Academic Year.
# For females, a weak positive relationship (correlation coefficient: 0.20) exists between the two variables.
#
# Case 4: Certificate vs. Academic_Year
#
# For males, there is a moderate negative relationship (correlation coefficient: -0.36) between the number of Certificates and Academic Year.
# For females, a weak negative relationship (correlation coefficient: -0.24) is observed.
#
# Case 5: Bachelors vs. Academic_Year
#
# For males, there is a weak negative relationship (correlation coefficient: -0.20) between the number of Bachelors degrees and Academic Year.
# For females, there is a weak positive relationship (correlation coefficient: 0.14).
#
# Case 6: Diploma vs. Academic_Year
#
# For males, there is a moderate positive relationship (correlation coefficient: 0.32) between the number of Diplomas and Academic Year.
# For females, the relationship is very weak (correlation coefficient: -0.04).
# Overall Observations:
#
# The strength and direction of the relationships between the number of degrees (dependent variables) and Academic Year (independent variable) vary across different degrees and genders.
# In some cases, there is a positive correlation (indicating an increase in degrees with higher Academic Year), while in others, there is a negative correlation.
# The strength of the relationships varies from very weak to moderate.
# The presence and nature of relationships also differ between males and females, suggesting that gender may play a role in these variations.
# These findings indicate that the relationship between Academic Year and the number of degrees earned is not uniform and can differ based on the specific degree and gender.

# %% [markdown]
# ## Question 5

# %% [markdown]
# You will now work on the simple linear regression model that predicts for the dependent variable. Treat 'Academic_Year' as an independent variable and use any of the two dependent variables you chose in Questions 3 as the dependent variables.
#
# **5a.** Fit a simple linear regression model between your dependent and independent variables. Generate and use the residual plot, the standard error, and the R^2 to assess the fit of each linear model. If the model is a good fit, interpret the slope and the intercept.
#
# In the same way, do it for other quantitative variables. Now change the categorical variable and replicate calculations. This should give rise to ten cases.
#
# **5b.** Summarize and present your findings in a sophisticated statistical terms.

# %% [markdown]
# **Answer 5a.**
#
# (Begin your answer by explicitly mentioning which three quantitative and two categorical variables you have chosen.)
#
# **Case 1.**

# %%
import pandas
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
import statsmodels.api as statsmodels
import seaborn as sns

# %%
#Case 1

df = pandas.read_csv(r'C:\Users\user\Hamdan\Hamdan.csv') 
df = pd.DataFrame(df)
df = df.set_index('Unnamed: 0', drop=True)
df.columns = df.columns.str.strip() 

def regression_equation(column_x, column_y):
    # fit the regression line using "statsmodels" library:
    X= df['Academic_Year'] 
    X = statsmodels.add_constant(X)
    Y = df['Bachelors']  
    regressionmodel = statsmodels.OLS(Y,X).fit() #OLS stands for "ordinary least squares"
    print('R2: ', round(regressionmodel.rsquared, 3))
    SE=np.sqrt(regressionmodel.mse_resid)
    print ('SE=', round(SE, 3))

     #display the correlation coefficient 
    correlation_coefficient=stats.pearsonr(df['Academic_Year'], Y)[0]
    print("correlation_coefficient=", round(correlation_coefficient,3))
    
    # extract regression parameters from model, rounded to 2 decimal places and print the regression equation:
    slope = round(regressionmodel.params[1],3)
    intercept = round(regressionmodel.params[0],3)
    print("Regression equation: "+column_y+" = ",slope,"* "+column_x+" + ",intercept)
    
    #display the scatter plot with the line of best fit
    plt.scatter(df['Academic_Year'], Y, color='green')
    plt.xlabel(column_x)
    plt.ylabel(column_y)
    plt.plot(df[column_x], regressionmodel.params[1]*df[column_x]+regressionmodel.params[0], color='red')
    plt.show()
    #display the residual plot
    sns.residplot(x = column_x,
              y = column_y,
              data = df)
    plt.show()
    #display the residual plot with SE
    sns.residplot(x = column_x,
              y = column_y,
              data = df)
    plt.axhline(y=SE, color='r', linestyle='--')
    plt.axhline(y=-SE, color='r', linestyle='--')
    plt.show()
regression_equation('Academic_Year', 'Bachelors')
# Out:
# R2:  0.006
# SE= 416.93
# correlation_coefficient= 0.079
# Regression equation: Bachelors =  13.968 * Academic_Year +  -27754.936

# %% [markdown]
# **Case 2.**

# %%
# Case 2 

df = pandas.read_csv(r'C:\Users\user\Hamdan\Hamdan.csv') 
df = pd.DataFrame(df)
df = df.set_index('Unnamed: 0', drop=True)
df.columns = df.columns.str.strip() 

def regression_equation(column_x, column_y):
    # fit the regression line using "statsmodels" library:
    X= df['Academic_Year'] 
    X = statsmodels.add_constant(X)
    Y = df['Certificate']  
    regressionmodel = statsmodels.OLS(Y,X).fit() #OLS stands for "ordinary least squares"
    print('R2: ', round(regressionmodel.rsquared, 3))
    SE=np.sqrt(regressionmodel.mse_resid)
    print ('SE=', round(SE, 3))

     #display the correlation coefficient 
    correlation_coefficient=stats.pearsonr(df['Academic_Year'], Y)[0]
    print("correlation_coefficient=", round(correlation_coefficient,3))
    
    # extract regression parameters from model, rounded to 2 decimal places and print the regression equation:
    slope = round(regressionmodel.params[1],3)
    intercept = round(regressionmodel.params[0],3)
    print("Regression equation: "+column_y+" = ",slope,"* "+column_x+" + ",intercept)
    
    #display the scatter plot with the line of best fit
    plt.scatter(df['Academic_Year'], Y, color='green')
    plt.xlabel(column_x)
    plt.ylabel(column_y)
    plt.plot(df[column_x], regressionmodel.params[1]*df[column_x]+regressionmodel.params[0], color='red')
    plt.show()
    #display the residual plot
    sns.residplot(x = column_x,
              y = column_y,
              data = df)
    plt.show()
    #display the residual plot with SE
    sns.residplot(x = column_x,
              y = column_y,
              data = df)
    plt.axhline(y=SE, color='r', linestyle='--')
    plt.axhline(y=-SE, color='r', linestyle='--')
    plt.show()
regression_equation('Academic_Year', 'Certificate')
# Out:
# R2:  0.007
# SE= 14.72
# correlation_coefficient= 0.082
# Regression equation: Certificate =  0.514 * Academic_Year +  -1020.229

# %% [markdown]
# **Case 3.**

# %%
# Case 3

df = pandas.read_csv(r'C:\Users\user\Hamdan\Hamdan.csv') 
df = pd.DataFrame(df)
df = df.set_index('Unnamed: 0', drop=True)
df.columns = df.columns.str.strip() 

def regression_equation(column_x, column_y):
    # fit the regression line using "statsmodels" library:
    X= df['Academic_Year'] 
    X = statsmodels.add_constant(X)
    Y = df['Diploma']  
    regressionmodel = statsmodels.OLS(Y,X).fit() #OLS stands for "ordinary least squares"
    print('R2: ', round(regressionmodel.rsquared, 3))
    SE=np.sqrt(regressionmodel.mse_resid)
    print ('SE=', round(SE, 3))

     #display the correlation coefficient 
    correlation_coefficient=stats.pearsonr(df['Academic_Year'], Y)[0]
    print("correlation_coefficient=", round(correlation_coefficient,3))
    
    # extract regression parameters from model, rounded to 2 decimal places and print the regression equation:
    slope = round(regressionmodel.params[1],3)
    intercept = round(regressionmodel.params[0],3)
    print("Regression equation: "+column_y+" = ",slope,"* "+column_x+" + ",intercept)
    
    #display the scatter plot with the line of best fit
    plt.scatter(df['Academic_Year'], Y, color='green')
    plt.xlabel(column_x)
    plt.ylabel(column_y)
    plt.plot(df[column_x], regressionmodel.params[1]*df[column_x]+regressionmodel.params[0], color='red')
    plt.show()
    #display the residual plot
    sns.residplot(x = column_x,
              y = column_y,
              data = df)
    plt.show()
    #display the residual plot with SE
    sns.residplot(x = column_x,
              y = column_y,
              data = df)
    plt.axhline(y=SE, color='r', linestyle='--')
    plt.axhline(y=-SE, color='r', linestyle='--')
    plt.show()
regression_equation('Academic_Year', 'Diploma')
# Out:
# R2:  0.054
# SE= 66.583
# correlation_coefficient= -0.232
# Regression equation: Diploma =  -6.742 * Academic_Year +  13644.886

# %% [markdown]
# **Case 4.**

# %%
# Case 4 

df = pandas.read_csv(r'C:\Users\user\Hamdan\Hamdan.csv') 
df = pd.DataFrame(df)
df = df.set_index('Unnamed: 0', drop=True)
df.columns = df.columns.str.strip() 

def regression_equation(column_x, column_y):
    # fit the regression line using "statsmodels" library:
    X= df['Academic_Year'] 
    X = statsmodels.add_constant(X)
    Y = df['Doctorate']  
    regressionmodel = statsmodels.OLS(Y,X).fit() #OLS stands for "ordinary least squares"
    print('R2: ', round(regressionmodel.rsquared, 3))
    SE=np.sqrt(regressionmodel.mse_resid)
    print ('SE=', round(SE, 3))

     #display the correlation coefficient 
    correlation_coefficient=stats.pearsonr(df['Academic_Year'], Y)[0]
    print("correlation_coefficient=", round(correlation_coefficient,3))
    
    # extract regression parameters from model, rounded to 2 decimal places and print the regression equation:
    slope = round(regressionmodel.params[1],3)
    intercept = round(regressionmodel.params[0],3)
    print("Regression equation: "+column_y+" = ",slope,"* "+column_x+" + ",intercept)
    
    #display the scatter plot with the line of best fit
    plt.scatter(df['Academic_Year'], Y, color='green')
    plt.xlabel(column_x)
    plt.ylabel(column_y)
    plt.plot(df[column_x], regressionmodel.params[1]*df[column_x]+regressionmodel.params[0], color='red')
    plt.show()
    #display the residual plot
    sns.residplot(x = column_x,
              y = column_y,
              data = df)
    plt.show()
    #display the residual plot with SE
    sns.residplot(x = column_x,
              y = column_y,
              data = df)
    plt.axhline(y=SE, color='r', linestyle='--')
    plt.axhline(y=-SE, color='r', linestyle='--')
    plt.show()
regression_equation('Academic_Year', 'Doctorate')
# Out:
# R2:  0.016
# SE= 2.129
# correlation_coefficient= 0.125
# Regression equation: Doctorate =  0.114 * Academic_Year +  -223.002

# %% [markdown]
# **Case 5.**
#
# (Begin your answer by explicitly mentioning which three quantitative and two categorical variables you have chosen.)

# %%
# Case 5. 

df = pandas.read_csv(r'C:\Users\user\Hamdan\Hamdan.csv') 
df = pd.DataFrame(df)
df = df.set_index('Unnamed: 0', drop=True)
df.columns = df.columns.str.strip() 

def regression_equation(column_x, column_y):
    # fit the regression line using "statsmodels" library:
    X= df['Academic_Year'] 
    X = statsmodels.add_constant(X)
    Y = df['Higher Diploma']  
    regressionmodel = statsmodels.OLS(Y,X).fit() #OLS stands for "ordinary least squares"
    print('R2: ', round(regressionmodel.rsquared, 3))
    SE=np.sqrt(regressionmodel.mse_resid)
    print ('SE=', round(SE, 3))

     #display the correlation coefficient 
    correlation_coefficient=stats.pearsonr(df['Academic_Year'], Y)[0]
    print("correlation_coefficient=", round(correlation_coefficient,3))
    
    # extract regression parameters from model, rounded to 2 decimal places and print the regression equation:
    slope = round(regressionmodel.params[1],3)
    intercept = round(regressionmodel.params[0],3)
    print("Regression equation: "+column_y+" = ",slope,"* "+column_x+" + ",intercept)
    
    #display the scatter plot with the line of best fit
    plt.scatter(df['Academic_Year'], Y, color='green')
    plt.xlabel(column_x)
    plt.ylabel(column_y)
    plt.plot(df[column_x], regressionmodel.params[1]*df[column_x]+regressionmodel.params[0], color='red')
    plt.show()
    #display the residual plot
    sns.residplot(x = column_x,
              y = column_y,
              data = df)
    plt.show()
    #display the residual plot with SE
    sns.residplot(x = column_x,
              y = column_y,
              data = df)
    plt.axhline(y=SE, color='r', linestyle='--')
    plt.axhline(y=-SE, color='r', linestyle='--')
    plt.show()
regression_equation('Academic_Year', 'Higher Diploma')
# Out:
# R2:  0.0
# SE= 24.836
# correlation_coefficient= 0.019
# Regression equation: Higher Diploma =  0.205 * Academic_Year +  -377.761

# %% [markdown]
# **Case 6.**
#
# (Begin your answer by explicitly mentioning which three quantitative and two categorical variables you have chosen.)

# %%
# Case 6

df = pandas.read_csv(r'C:\Users\user\Hamdan\Hamdan.csv') 
df = pd.DataFrame(df)
df = df.set_index('Unnamed: 0', drop=True)
df.columns = df.columns.str.strip() 

def regression_equation(column_x, column_y):
    # fit the regression line using "statsmodels" library:
    X= df['Academic_Year'] 
    X = statsmodels.add_constant(X)
    Y = df['Masters']  
    regressionmodel = statsmodels.OLS(Y,X).fit() #OLS stands for "ordinary least squares"
    print('R2: ', round(regressionmodel.rsquared, 3))
    SE=np.sqrt(regressionmodel.mse_resid)
    print ('SE=', round(SE, 3))

     #display the correlation coefficient 
    correlation_coefficient=stats.pearsonr(df['Academic_Year'], Y)[0]
    print("correlation_coefficient=", round(correlation_coefficient,3))
    
    # extract regression parameters from model, rounded to 2 decimal places and print the regression equation:
    slope = round(regressionmodel.params[1],3)
    intercept = round(regressionmodel.params[0],3)
    print("Regression equation: "+column_y+" = ",slope,"* "+column_x+" + ",intercept)
    
    #display the scatter plot with the line of best fit
    plt.scatter(df['Academic_Year'], Y, color='green')
    plt.xlabel(column_x)
    plt.ylabel(column_y)
    plt.plot(df[column_x], regressionmodel.params[1]*df[column_x]+regressionmodel.params[0], color='red')
    plt.show()
    #display the residual plot
    sns.residplot(x = column_x,
              y = column_y,
              data = df)
    plt.show()
    #display the residual plot with SE
    sns.residplot(x = column_x,
              y = column_y,
              data = df)
    plt.axhline(y=SE, color='r', linestyle='--')
    plt.axhline(y=-SE, color='r', linestyle='--')
    plt.show()
regression_equation('Academic_Year', 'Masters')
# Out:
# R2:  0.006
# SE= 128.467
# correlation_coefficient= 0.076
# Regression equation: Masters =  4.169 * Academic_Year +  -8296.441

# %% [markdown]
# **Answer 5b.**

# %% [markdown]
# Findings for Simple Linear Regression Models
#
# Case 1 - Bachelors Degree
#
# R-squared (R²): 0.006
# Standard Error (SE): 416.93
# Correlation Coefficient: 0.079
# Regression Equation: Bachelors = 13.968 * Academic_Year - 27754.936
#
# Case 2 - Certificate
#
# R-squared (R²): 0.007
# Standard Error (SE): 14.72
# Correlation Coefficient: 0.082
# Regression Equation: Certificate = 0.514 * Academic_Year - 1020.229
#
# Case 3 - Diploma
#
# R-squared (R²): 0.054
# Standard Error (SE): 66.583
# Correlation Coefficient: -0.232
# Regression Equation: Diploma = -6.742 * Academic_Year + 13644.886
#
# Case 4 - Doctorate
#
# R-squared (R²): 0.016
# Standard Error (SE): 2.129
# Correlation Coefficient: 0.125
# Regression Equation: Doctorate = 0.114 * Academic_Year - 223.002
#
# Case 5 - Higher Diploma
#
# R-squared (R²): 0.0
# Standard Error (SE): 24.836
# Correlation Coefficient: 0.019
# Regression Equation: Higher Diploma = 0.205 * Academic_Year - 377.761
#
# Case 6 - Masters Degree
#
# R-squared (R²): 0.006
# Standard Error (SE): 128.467
# Correlation Coefficient: 0.076
# Regression Equation: Masters = 4.169 * Academic_Year - 8296.441
# Summary of Findings:
#
# R-squared (R²): R-squared measures the goodness of fit of the model. In all cases, the R-squared values are quite low, indicating that the linear regression models do not explain a significant portion of the variance in the dependent variables.
#
# Standard Error (SE): The standard error measures the accuracy of the model's predictions. Higher SE values indicate less accurate predictions. The SE varies across cases, with some models having higher errors than others.
#
# Correlation Coefficient: The correlation coefficient represents the strength and direction of the relationship between the independent and dependent variables. Cases 2 and 4 have the highest positive correlation coefficients, while case 3 has a negative correlation.
#
# Regression Equation: The regression equation for each case provides the relationship between the academic year and the dependent variable. Interpretation of the slope and intercept depends on the context of the specific variable and may require domain knowledge.
#
# Overall, the linear regression models in these cases do not provide a strong fit to the data, as indicated by the low R-squared values.

# %% [markdown]
# ## Question 6

# %% [markdown]
# The conservation and rehabilitation of local flora and natural habitats comes under part of the biodiversity program of Environment Agency, Abu Dhabi (EAD). A sophisticated and high-tech monitoring system provides the following annual production of plants within native plant nursery. The number of floras in a particular year is written on top of that column which may be used  in calculations.
#
# ![BD.jpg](attachment:BD.jpg)
#
# Answer the following questions.

# %% [markdown]
# **6a.** Calculate the percentage increase in plants products from year Y1 to year Y2, where both years Y1 and Y2 are obtained by running the code below.

# %%
# Run this code which will provide you the years for which you need to work
t=random.randint(2014, 2018)
s=random.randint(2019, 2022)
print("From Y1=", t, "to  Y2 =", s)
# Out:
# From Y1= 2016 to  Y2 = 2021

# %%
# Replace the following lines with your actual plant production values for Y1 and Y2
Y1 =  2016
Y2 =  2021

# Calculate the percentage increase
percentage_increase = ((Y2 - Y1) / Y1) * 100

# Print the result
print(f"From Y1 = {Y1} to Y2 = {Y2}, Percentage Increase in Plant Production: {percentage_increase:.1f}%")
# Out:
# From Y1 = 2016 to Y2 = 2021, Percentage Increase in Plant Production: 0.2%

# %% [markdown]
# **Provide your answer here.**
#
# **Answer 6a:** Percentage Increase = 0.2 %

# %% [markdown]
# **6b.** Which two years the percentage increase in the annual production of plants was equal to P%? where P is to be found by running the code below and it is calculated up to one decimal place.

# %%
# Run this code to get the percentage
t=random.choice([5.9,13.3,62.3,5.7,8.6,31.6,12, 20, 83.9, 71.6, 14.8, 42.9, 94.7,94.4, 86.3])
print("Percentage = P% =", t, "%")
# Out:
# Percentage = P% = 31.6 %

# %%
# Define the annual production values for the years 2014 to 2022
annual_production = [170000, 180000, 204000, 331000 , 350000 , 380000 , 500000 , 500000,560000]

# %%
# Define the years corresponding to the data
years = list(range(2014, 2023))

# Initialize a list to store matching years
matching_years = []

# Calculate the percentage increase and find matching years
for i in range(len(annual_production) - 1):
    year1 = years[i]
    year2 = years[i + 1]
    increase = ((annual_production[i + 1] - annual_production[i]) / annual_production[i]) * 100

    if round(increase, 1) == t:
        matching_years.append((year1, year2))

print("Years with a percentage increase of", t, "%:", matching_years)
# Out:
# Years with a percentage increase of 31.6 %: [(2019, 2020)]

# %% [markdown]
# **Provide your answer here.**
#
# **Answer 6b:** Year 2014 to Year 2015

# %% [markdown]
# ## Question 7

# %% [markdown]
# Under the long-term marine water quality monitoring program of the Environment Agency Abu Dhabi (EAD), a red tide monitoring project was launched to look for harmful algal blooms (HAB) in marine water. The project accounted for number of such HAB incidents in Abu Dhabi from 2002 to 2022. Use your statistical skills of this course IDS-103, to make two strong observations (non-trivial) to be reported to EAD from the graph below.
#
# ![BD2.jpg](attachment:BD2.jpg)

# %% [markdown]
# **Answer 7:**

# %%
import matplotlib.pyplot as plt

# Years from 2002 to 2022
years = list(range(2002, 2023))

# Number of HAB incidents for each year
hab_incidents = [1, 3, 4, 4, 5, 6, 8, 16, 17, 19, 28, 21, 24, 30, 24, 18, 23, 17, 13, 14, 14]

# Create a bar chart
plt.figure(figsize=(12, 6))
plt.bar(years, hab_incidents, color='skyblue')
plt.title('HAB Incidents in Abu Dhabi (2002-2022)')
plt.xlabel('Year')
plt.ylabel('Number of HAB Incidents')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Calculate the average number of HAB incidents over the years
average_incidents = sum(hab_incidents) / len(hab_incidents)
print(f"Average number of HAB incidents: {average_incidents:.2f}")
# Out:
# Average number of HAB incidents: 14.71

# %%
# Identify years with above-average incidents
above_average_years = [year for year, incidents in zip(years, hab_incidents) if incidents > average_incidents]
print(f"Years with above-average incidents: {above_average_years}")
# Out:
# Years with above-average incidents: [2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019]

# %%
# Find the year with the highest number of HAB incidents
max_incidents_year = years[hab_incidents.index(max(hab_incidents))]
print(f"Year with the highest number of HAB incidents: {max_incidents_year}")
# Out:
# Year with the highest number of HAB incidents: 2015
